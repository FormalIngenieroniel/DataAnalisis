# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(np.random.randn(3,2), index=['a','c','e'], columns = ['one','two'])
df
# Out:
#         one       two
# a -0.808868  0.567444
# c -0.245247  1.154126
# e  0.990430  2.500158

# %%
df = df.reindex(['a','b','c','d','e'])
df
# Out:
#         one       two
# a -0.808868  0.567444
# b       NaN       NaN
# c -0.245247  1.154126
# d       NaN       NaN
# e  0.990430  2.500158

# %%
df.isnull()
# Out:
#      one    two
# a  False  False
# b   True   True
# c  False  False
# d   True   True
# e  False  False

# %%
df2 = df.dropna()
df2
# Out:
#         one       two
# a -0.808868  0.567444
# c -0.245247  1.154126
# e  0.990430  2.500158

# %%
data2 = [[22,'2017',0.20],[100,'0.33',1.112],[6,'12',0.3]]
df2 = pd.DataFrame(data2, columns = ['col1','col2','col3'])
df2
# Out:
#    col1  col2   col3
# 0    22  2017  0.200
# 1   100  0.33  1.112
# 2     6    12  0.300

# %%
df2.dtypes
# Out:
# col1      int64
# col2     object
# col3    float64
# dtype: object

# %%
df2['col2']=pd.to_numeric(df2['col2'])
df2.dtypes
# Out:
# col1      int64
# col2    float64
# col3    float64
# dtype: object
