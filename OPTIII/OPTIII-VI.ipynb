# %%
#Se comienza con el razonamiento del pnt 1 del taller planteando las hipotesis (nula y no nula)
#Nula: No nos roban si la media es igual a 100 gramos, si es menor se comple la otra hipotesis (se llama nula pq es la afirmacion original)
#No confundir las distribuciones, la primera es de las cajas (poblacion) la otra sera de las medias de los grupos de tamaño n
#Se define por el estudiante el nivel de significacia para poder determinar un juicio de valor (los cintificos ponen 5% pero de pende del contexto)
#La significancia se pone como un limite en la normal de las medias para ver cuando el limite de lejercicio (en este caso 99) puede ser muy probable o poco probable
#p=(x rayita <=99) 16%

# %%
#pnt2 media= 18.2 desv= 2
#     n=202       x rayita= 20
#Se opera la desv para obtener la poblacional y usarel cdf con los datos (20, 18.2 y la desv operada)

import scipy
import numpy as np
import seaborn as sns

pnt2 = 1 - scipy.stats.norm.cdf(20,18.2,0.14)

#Ho = Este año no es mas caliente (si es probable (mayor a 5) es esta)
#Ha = Este año es mas caliente (Esta fue)

pnt2

#Cual es la probabilidad de tomar una muestra n y que el promedio de eso
# Out:
# 0.0
