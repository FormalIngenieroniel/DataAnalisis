# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb


a = np.random.normal(170,10,1000)

df = pd.DataFrame({"Altura (cm)":a})

df

h = plt.hist(df)

media = df.mean()

mediana = df.median()

df2 = pd.read_csv('./titanic.csv')
df3 = df2[(df2["Age"] > 30) & (df2["Age"] < 40)][{"Name","Age"}]
df3

#punto 1 = 887

pnt1 = df2[(df2["Age"] > 18) & (df2["Sex"] == "female")]
pnt1

#punto 2 = 122

pnt2 = df2[(df2["Pclass"] == 1) & (df2["Sex"] == "male")]
pnt2

#punto 3 = 283

pnt3 = df2[(df2["SibSp"] >= 1)]
pnt3

#punto 4 = 11

pnt4 = df2[(df2["Sex"] == "female") & ((df2["Pclass"] == 1) | (df2["Pclass"] == 2)) & ((df2["Age"] > 60) | (df2["Age"] < 10))]
pnt4.count()
# Out:
# <ipython-input-42-cdce59a41b64>:20: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df3 = df2[(df2["Age"] > 30) & (df2["Age"] < 40)][{"Name","Age"}]
# PassengerId    11
# Survived       11
# Pclass         11
# Name           11
# Sex            11
# Age            11
# SibSp          11
# Parch          11
# Ticket         11
# Fare           11
# Cabin           4
# Embarked       10
# dtype: int64
