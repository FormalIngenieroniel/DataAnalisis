# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./titanic.csv')

# %% [markdown]
# Tablas de contingencia

# %%
pd.crosstab(index=df["Sex"], columns=df["Survived"], margins=True)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %% [markdown]
# P(Sex=female) = 314/891 = 0.35
# P(sobrevive | es mujer) = 233/314 = 0.74

# %%
sns.countplot(df, x='Sex', hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(df, x='Pclass', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
pd.crosstab(index=df["Pclass"], columns=df["Survived"], margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %% [markdown]
# p(sobrevive | clase 1) = 136/216 = 0.63
#
# p(sobrevive | clase 2) = 0.47
#
# p(sobrevive | clase 3 ) = 0.24

# %%
#Clase segunda parte

dfI = pd.read_csv('./german_credit_data (1).csv')

# %%
dfI.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  Risk
# 0           1169         6             radio/TV  good
# 1           5951        48             radio/TV   bad
# 2           2096        12            education  good
# 3           7882        42  furniture/equipment  good
# 4           4870        24                  car   bad

# %%
sns.countplot(dfI, x='Sex', hue='Purpose')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
x = dfI["Job"]
y = dfI["Credit amount"]

plt.bar(x,y)
# Out:
# <BarContainer object of 1000 artists>
