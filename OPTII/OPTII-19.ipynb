# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing, svm
import numpy as np

# %%
df = pd.read_csv("/content/USDCOP=X.csv",parse_dates=True)
df = df[{"Adj Close"}]
# Out:
# <ipython-input-3-b8954ccd16fe>:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = df[{"Adj Close"}]

# %%
df.plot()
# Out:
# <Axes: >

# %%
regr = LinearRegression()

x = df.index.values.reshape(-1, 1)
y = df['Adj Close'].values.reshape(-1, 1)

regr.fit(x,y)

y_pred = regr.predict(x)
plt.plot(x, y, color ='b')
plt.plot(x, y_pred, color ='r')
plt.plot(x, y - y_pred, color ='k')

plt.show()

# %% [markdown]
# Serie Air Passenger

# %%
dfII = pd.read_csv("/content/airline-passengers (4).csv",parse_dates=True)

regr = LinearRegression()

x = dfII.index.values.reshape(-1, 1)
y = dfII['Passengers'].values.reshape(-1, 1)

regr.fit(x,y)

y_pred = regr.predict(x)
plt.plot(x, y, color ='b')
plt.plot(x, y_pred, color ='r')
plt.plot(x, y - y_pred, color ='k')

plt.show()

# %% [markdown]
# Serie Shampoos

# %%
dfIII = pd.read_csv("/content/shampoo-sales.csv",parse_dates=True)

regr = LinearRegression()

x = dfIII.index.values.reshape(-1, 1)
y = dfIII['Sales of shampoo over a three year period'].values.reshape(-1, 1)

regr.fit(x,y)

y_pred = regr.predict(x)
plt.plot(x, y, color ='b')
plt.plot(x, y_pred, color ='r')
plt.plot(x, y - y_pred, color ='k')

plt.show()
