# %%
#Escalado, es importante conocer las variables con las que se trabaja para esclar los datos y mejorar los algoritmos (normalmente distancia entre puntos)

import statistics

list = [1500000,1525000,1520000]
print("List : " + str(list))

st_dev = statistics.pstdev(list)
print("Standard deviation of the given list: " + str(st_dev))

media = 1515000
coso1 = (1520000-media)/st_dev
coso1
# Out:
# List : [1500000, 1525000, 1520000]
# Standard deviation of the given list: 10801.234497346433
# 0.46291004988627577

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd

# %%
from os import lseek
ls = {'edad':['23','25','45'], 'sueldo':['1500000','1525000','1520000']}
df = pd.DataFrame(ls)

objeto = MinMaxScaler()
objeto.fit(df)
objeto.transform(df)
# Out:
# array([[0.        , 0.        ],
#        [0.09090909, 1.        ],
#        [1.        , 0.8       ]])
