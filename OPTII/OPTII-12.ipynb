# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Df = pd.read_csv('/content/notas.csv')
DfIII = Df
Df
# Out:
#     id  NotasCompuIntermedia  NotasBigData
# 0    0                   1.4           3.2
# 1    1                   3.5           0.7
# 2    2                   2.8           1.7
# 3    3                   1.0           2.8
# 4    4                   1.9           4.4
# 5    5                   4.2           3.3
# 6    6                   0.1           3.5
# 7    7                   2.1           4.2
# 8    8                   3.8           2.6
# 9    9                   1.6           3.8
# 10  10                   1.8           2.7
# 11  11                   2.4           1.8
# 12  12                   4.0           3.1
# 13  13                   1.9           4.1
# 14  14                   2.1           3.8
# 15  15                   2.1           3.5
# 16  16                   4.7           5.0
# 17  17                   4.7           3.9
# 18  18                   3.5           4.5
# 19  19                   2.9           5.0
# 20  20                   3.2           2.2
# ...

# %% [markdown]
# Si nos ubicamos en el estudiante 10, veremos que el curso que tiene una nota mayor es "BigData" pues 2.7 > 1.8.
#
# Mientras que en el estudiante 16, veremos que el curso que tiene una nota mayor es "BigData" pues 5.0 > 4.7.
#
# Por lo tanto es correcto afirmar que ambos estudiantes tuvieron mejor desempeño en "BigData"
#
# Sin embargo a continuacion se hara un analisis mas exaustivo teniendo en cuenta las notas de los demas estudiantes

# %%
DfIII.drop(['id'], axis=1, inplace=True)
DfII = DfIII.iloc[[10,16]]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
y = StandardScaler()
y.fit(DfIII)
DfIII = y.transform(DfIII)

# %%
DfIV = pd.DataFrame(DfIII)
DfIV = DfIV.rename(columns={DfIV.columns[0]: 'NotasCompuIntermediaStandar', DfIV.columns[1]: 'NotasBigDataStandar'})
DfIV.hist()
# Out:
# array([[<Axes: title={'center': 'NotasCompuIntermediaStandar'}>,
#         <Axes: title={'center': 'NotasBigDataStandar'}>]], dtype=object)

# %%
DfV = DfIV.iloc[[10,16]]
DfVI = Df.iloc[[10,16]]
unioned_df = pd.concat([DfV,DfVI], axis=1)
unioned_df
# Out:
#     NotasCompuIntermediaStandar  NotasBigDataStandar  NotasCompuIntermedia  \
# 10                    -0.644128            -0.784846                   1.8
# 16                     1.835481             1.290035                   4.7
#
#     NotasBigData
# 10           2.7
# 16           5.0

# %% [markdown]
# Aqui podemos observar que en el caso del estudiante 10, sus notas estan a menor desviaciones estandares a pesar de estar bajas. Esto quiere decir que estuvieron muy cerca de la media de las notas que sacaron los estudiantes del curso.
#
# Para el estudiante 16 observamos que sus notas estan un poco mas alejadas de la media, lo que quiere decir que no representa muy bien un valor central para los estuantes de l curos en general.
#
# Si añadimos esta parte al anterior analisis que se realizo en este documento, podemos determinar que el estudiante 10 tiene un rendimiento mas cercano a la media que el estudiante 16 y que el valor de las notas quizas se puede deber a la dureza con la que califica el profesor. Si partimos de este orden de ideas en estudiante 10 tuvo mejor rendimiento en "CompuIntermedia" y el 16 en "BigData".
